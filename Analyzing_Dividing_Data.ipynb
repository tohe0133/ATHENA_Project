# %% [markdown]
# <a href="https://colab.research.google.com/github/tohe0133/ATHENA_Project/blob/main/Analyzing_Dividing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
root_dir = '/content/gdrive/MyDrive/'
base_dir = root_dir + 'FIMI_dataset/'
# Out:
# Mounted at /content/gdrive/

# %%
dataset_fake = pd.read_csv(base_dir + 'DataSet_Misinfo_FAKE.csv')
dataset_fake['label'] = 'fake'
#dataset_fake = dataset_fake.iloc[:1000,:]
dataset_real = pd.read_csv(base_dir + 'DataSet_Misinfo_TRUE.csv')
dataset_real['label'] = 'true'
#dataset_real = dataset_real.iloc[:1000,:]
df = pd.concat([dataset_real, dataset_fake], ignore_index=True)
df = df.drop('Unnamed: 0', axis=1)

# %%
# df used to have 78617 rows
# .dropna() reduces it to have 78588 rows
# .drop_duplicates() reduces it to 68604 rows

df = df.dropna()
df = df.drop_duplicates()
df.reset_index(drop=True, inplace=True)

df
# Out:
#                                                     text label
# 0      The head of a conservative Republican faction ...  true
# 1      Transgender people will be allowed for the fir...  true
# 2      The special counsel investigation of links bet...  true
# 3      Trump campaign adviser George Papadopoulos tol...  true
# 4      President Donald Trump called on the U.S. Post...  true
# ...                                                  ...   ...
# 68599  Apparently, the new Kyiv government is in a hu...  fake
# 68600  The USA wants to divide Syria.\r\n\r\nGreat Br...  fake
# 68601  The Ukrainian coup d'etat cost the US nothing ...  fake
# 68602  The European Parliament falsifies history by d...  fake
# 68603  A leading FSB officer, Segey Beseda, said duri...  fake
#
# [68604 rows x 2 columns]

# %%
#Preprocessing (removing \n and \r)
df['text'] = df['text'].str.replace('\n', '')
df['text'] = df['text'].str.replace('\r', '')
df['text'] = df['text'].str.replace('\xa0', '')
df['text'] = df['text'].str.replace('\u200e', '')
df['text'] = df['text'].str.replace('\u200f', '')
df['text'] = df['text'].str.replace('\u200b', '')
df['text'] = df['text'].str.replace('\u200a', '')
df['text'] = df['text'].str.replace('\u200c', '')
df['text'] = df['text'].str.replace('\u202f', '')
df['text'] = df['text'].str.replace('\u2002', '')
df['text'] = df['text'].str.replace('\u202a', '')
df['text'] = df['text'].str.replace('\u2005', '')
df['text'] = df['text'].str.replace('\u2009', '')
df['text'] = df['text'].str.replace('\u2008', '')
df['text'] = df['text'].str.replace('\u2028', '')
df['text'] = df['text'].str.replace('\u200d', '')
df['text'] = df['text'].str.replace('\uf022', '')
df['text'] = df['text'].str.replace('\uf0dd', '')
df['text'] = df['text'].str.replace('\xad', '')
df['text'] = df['text'].str.replace('\x8c', '')
df['text'] = df['text'].str.replace('\x8d', '')
df['text'] = df['text'].str.replace('\x8e', '')
df['text'] = df['text'].str.replace('\x8f', '')
df['text'] = df['text'].str.replace('\x9f', '')
df['text'] = df['text'].str.replace('\x9a', '')
df['text'] = df['text'].str.replace('\x9c', '')
df['text'] = df['text'].str.replace('\x9d', '')
df['text'] = df['text'].str.replace('\x80', '')
df['text'] = df['text'].str.replace('\x81', '')
df['text'] = df['text'].str.replace('\x82', '')
df['text'] = df['text'].str.replace('\x83', '')
df['text'] = df['text'].str.replace('\x87', '')
df['text'] = df['text'].str.replace('\x90', '')
df['text'] = df['text'].str.replace('\x91', '')
df['text'] = df['text'].str.replace('\x92', '')
df['text'] = df['text'].str.replace('\x93', '')
df['text'] = df['text'].str.replace('\x94', '')
df['text'] = df['text'].str.replace('\x95', '')
df['text'] = df['text'].str.replace('\x96', '')
df['text'] = df['text'].str.replace('\x97', '')
df['text'] = df['text'].str.replace('\x98', '')
df['text'] = df['text'].str.replace('\x99', '')
df['text'] = df['text'].str.replace('\ufeff', '')
df['text'] = df['text'].str.replace('\uf44a', '')
df['text'] = df['text'].str.replace('\uf4a9', '')
df['text'] = df['text'].str.replace('\uf1f8', '')
df['text'] = df['text'].str.replace('\uf1fa', '')
df['text'] = df['text'].str.replace('\uf64c', '')
df['text'] = df['text'].str.replace('\uf6a8', '')
df['text'] = df['text'].str.replace('\uf0b7', '')
df['text'] = df['text'].str.replace('\uf3fb', '')
df['text'] = df['text'].str.replace('\uf602', '')
df['text'] = df['text'].str.replace('\uf50d', '')
df['text'] = df['text'].str.replace('\uf438', '')
df['text'] = df['text'].str.replace('̌', '')
df['text'] = df['text'].str.replace('˚', '')
df['text'] = df['text'].str.replace('°', '')
df['text'] = df['text'].str.replace('¸', ',')
df['text'] = df['text'].str.replace('“', '"')
df['text'] = df['text'].str.replace('”', '"')
df['text'] = df['text'].str.replace('„', '"')
df['text'] = df['text'].str.replace('»', '"')
df['text'] = df['text'].str.replace('«', '"')
df['text'] = df['text'].str.replace('‹', '"')
df['text'] = df['text'].str.replace('›', '"')
df['text'] = df['text'].str.replace('’', '')
df['text'] = df['text'].str.replace('´', '')
df['text'] = df['text'].str.replace('″', '"')
df['text'] = df['text'].str.replace('′', '"')
df['text'] = df['text'].str.replace('●', '')
df['text'] = df['text'].str.replace('•', '')
df['text'] = df['text'].str.replace('■', '')
df['text'] = df['text'].str.replace('►', '')
df['text'] = df['text'].str.replace('¶', '')
df['text'] = df['text'].str.replace('±', '')
df['text'] = df['text'].str.replace('·', '')
df['text'] = df['text'].str.replace('️', '')
df['text'] = df['text'].str.replace('💔', '')
df['text'] = df['text'].str.replace('🍾', '')
df['text'] = df['text'].str.replace('🎈', '')
df['text'] = df['text'].str.replace('🎉', '')
df['text'] = df['text'].str.replace('💖', '')
df['text'] = df['text'].str.replace('💛', '')
df['text'] = df['text'].str.replace('💙', '')
df['text'] = df['text'].str.replace('💚', '')
df['text'] = df['text'].str.replace('❤', '')
df['text'] = df['text'].str.replace('😥', '')
df['text'] = df['text'].str.replace('♡', '')
df['text'] = df['text'].str.replace('💜', '')
df['text'] = df['text'].str.replace('😔', '')
df['text'] = df['text'].str.replace('🙄', '')
df['text'] = df['text'].str.replace('🔥', '')
df['text'] = df['text'].str.replace('😘', '')
df['text'] = df['text'].str.replace('😭', '')
df['text'] = df['text'].str.replace('🏽', '')
df['text'] = df['text'].str.replace('💪', '')
df['text'] = df['text'].str.replace('⚡', '')
df['text'] = df['text'].str.replace('🐸', '')
df['text'] = df['text'].str.replace('😡', '')
df['text'] = df['text'].str.replace('😂', '')
df['text'] = df['text'].str.replace('☻', '')
df['text'] = df['text'].str.replace('☹', '')
df['text'] = df['text'].str.replace('😉', '')
df['text'] = df['text'].str.replace('🤔', '')
df['text'] = df['text'].str.replace('🙂', '')
df['text'] = df['text'].str.replace('😀', '')
df['text'] = df['text'].str.replace('✨', '')
df['text'] = df['text'].str.replace('👍', '')
df['text'] = df['text'].str.replace('😞', '')
df['text'] = df['text'].str.replace('🙂', '')
df['text'] = df['text'].str.replace('👌', '')
df['text'] = df['text'].str.replace('🐝', '')
df['text'] = df['text'].str.replace('🌎', '')
df['text'] = df['text'].str.replace('👎', '')
df['text'] = df['text'].str.replace('😳', '')
df['text'] = df['text'].str.replace('💩', '')
df['text'] = df['text'].str.replace('👾', '')
df['text'] = df['text'].str.replace('👻', '')
df['text'] = df['text'].str.replace('😄', '')
df['text'] = df['text'].str.replace('😿', '')
df['text'] = df['text'].str.replace('🚀', '')
df['text'] = df['text'].str.replace('🐽', '')
df['text'] = df['text'].str.replace('🙈', '')
df['text'] = df['text'].str.replace('♥', '')
df['text'] = df['text'].str.replace('❄', '')
df['text'] = df['text'].str.replace('🏻', '')
df['text'] = df['text'].str.replace('⛏', '')
df['text'] = df['text'].str.replace('🎙', '')
df['text'] = df['text'].str.replace('👏', '')
df['text'] = df['text'].str.replace('★', '')
df['text'] = df['text'].str.replace('🌴', '')
df['text'] = df['text'].str.replace('💯', '')
df['text'] = df['text'].str.replace('😲', '')
df['text'] = df['text'].str.replace('😬', '')
df['text'] = df['text'].str.replace('⚾', '')
df['text'] = df['text'].str.replace('♀', '')
df['text'] = df['text'].str.replace('🏃', '')
df['text'] = df['text'].str.replace('🌺', '')
df['text'] = df['text'].str.replace('✏', '')
df['text'] = df['text'].str.replace('😝', '')
df['text'] = df['text'].str.replace('💕', '')
df['text'] = df['text'].str.replace('💝', '')
df['text'] = df['text'].str.replace('💥', '')
df['text'] = df['text'].str.replace('💋', '')
df['text'] = df['text'].str.replace('😱', '')
df['text'] = df['text'].str.replace('🎶', '')
df['text'] = df['text'].str.replace('🎃', '')
df['text'] = df['text'].str.replace('🚨', '')
df['text'] = df['text'].str.replace('⏰', '')
df['text'] = df['text'].str.replace('⚓', '')
df['text'] = df['text'].str.replace('♞', '')
df['text'] = df['text'].str.replace('♦', '')
df['text'] = df['text'].str.replace('☕', '')
df['text'] = df['text'].str.replace('☮', '')
df['text'] = df['text'].str.replace('😍', '')
df['text'] = df['text'].str.replace('🌍', '')
df['text'] = df['text'].str.replace('🤕', '')
df['text'] = df['text'].str.replace('🕶', '')
df['text'] = df['text'].str.replace('😎', '')
df['text'] = df['text'].str.replace('😛', '')
df['text'] = df['text'].str.replace('😃', '')
df['text'] = df['text'].str.replace('✒', '')
df['text'] = df['text'].str.replace('🧀', '')
df['text'] = df['text'].str.replace('🙁', '')
df['text'] = df['text'].str.replace('❖', '')
df['text'] = df['text'].str.replace('❦', '')
df['text'] = df['text'].str.replace('☢', '')
df['text'] = df['text'].str.replace('☄', '')
df['text'] = df['text'].str.replace('❌', '')
df['text'] = df['text'].str.replace('ℂ', '')
df['text'] = df['text'].str.replace('�', '')
df['text'] = df['text'].str.replace('✪', '')
df['text'] = df['text'].str.replace('🖤', '')
df['text'] = df['text'].str.replace('🙏', '')
df['text'] = df['text'].str.replace('🙃', '')
df['text'] = df['text'].str.replace('♔', '')
df['text'] = df['text'].str.replace('😩', '')
df['text'] = df['text'].str.replace('♕', '')
df['text'] = df['text'].str.replace('🌙', '')
df['text'] = df['text'].str.replace('🕊', '')
df['text'] = df['text'].str.replace('😒', '')
df['text'] = df['text'].str.replace('🌹', '')
df['text'] = df['text'].str.replace('😏', '')
df['text'] = df['text'].str.replace('💸', '')
df['text'] = df['text'].str.replace('Ⓥ', '')
df['text'] = df['text'].str.replace('🏳', '')
df['text'] = df['text'].str.replace('🌈', '')
df['text'] = df['text'].str.replace('👇', '')
df['text'] = df['text'].str.replace('◆', '')
df['text'] = df['text'].str.replace('🙃', '')
df['text'] = df['text'].str.replace('👊', '')
df['text'] = df['text'].str.replace('😈', '')
df['text'] = df['text'].str.replace('🏾', '')
df['text'] = df['text'].str.replace('😫', '')
df['text'] = df['text'].str.replace('😯', '')
df['text'] = df['text'].str.replace('🖖', '')
df['text'] = df['text'].str.replace('👽', '')
df['text'] = df['text'].str.replace('🍑', '')
df['text'] = df['text'].str.replace('💻', '')
df['text'] = df['text'].str.replace('👨', '')
df['text'] = df['text'].str.replace('🌞', '')
df['text'] = df['text'].str.replace('🚴', '')
df['text'] = df['text'].str.replace('🚽', '')
df['text'] = df['text'].str.replace('🌟', '')
df['text'] = df['text'].str.replace('❗', '')
df['text'] = df['text'].str.replace('✿', '')
df['text'] = df['text'].str.replace('🌊', '')
df['text'] = df['text'].str.replace('🍕', '')
df['text'] = df['text'].str.replace('🌏', '')
df['text'] = df['text'].str.replace('🗽', '')
df['text'] = df['text'].str.replace('🍒', '')
df['text'] = df['text'].str.replace('♓', '')
df['text'] = df['text'].str.replace('🕹', '')
df['text'] = df['text'].str.replace('♫', '')
df['text'] = df['text'].str.replace('♢', '')
df['text'] = df['text'].str.replace('Ξ', '')
df['text'] = df['text'].str.replace('✟', '')
df['text'] = df['text'].str.replace('∞', '')
df['text'] = df['text'].str.replace('˘', '')
df['text'] = df['text'].str.replace('☆', '')
df['text'] = df['text'].str.replace('✓', '')
df['text'] = df['text'].str.replace('✔', '')
df['text'] = df['text'].str.replace('†', '')
df['text'] = df['text'].str.replace('℅', '')
df['text'] = df['text'].str.replace('￼', '')
df['text'] = df['text'].str.replace('⇩', '')
df['text'] = df['text'].str.replace('↑', '')
df['text'] = df['text'].str.replace('©', '')
df['text'] = df['text'].str.replace('®', '')
df['text'] = df['text'].str.replace('™', '')
df['text'] = df['text'].str.replace('¹', '')
df['text'] = df['text'].str.replace('º', '')
df['text'] = df['text'].str.replace('ª', '')
df['text'] = df['text'].str.replace('³', '')
df['text'] = df['text'].str.replace('́', '')
df['text'] = df['text'].str.replace('¨', '')
df['text'] = df['text'].str.replace('˜', '')
df['text'] = df['text'].str.replace('ø', '')
df['text'] = df['text'].str.replace('§', '')
df['text'] = df['text'].str.replace('⁄', '/')
df['text'] = df['text'].str.replace('÷', '/')
df['text'] = df['text'].str.replace('≈', '=')
df['text'] = df['text'].str.replace('‘', '"')
df['text'] = df['text'].str.replace('‚', ',')
df['text'] = df['text'].str.replace('−', '-')
df['text'] = df['text'].str.replace('→', '-')
df['text'] = df['text'].str.replace('¬', '-')
df['text'] = df['text'].str.replace('➡', '-')
df['text'] = df['text'].str.replace('←', '-')
df['text'] = df['text'].str.replace('≫', '-')
df['text'] = df['text'].str.replace('–', '-')
df['text'] = df['text'].str.replace('‒', '-')
df['text'] = df['text'].str.replace('‑', '-')
df['text'] = df['text'].str.replace('—', '-')
df['text'] = df['text'].str.replace('‐', '-')
df['text'] = df['text'].str.replace('―', '-')
df['text'] = df['text'].str.replace('‒', '-')
df['text'] = df['text'].str.replace('̄', '-')
df['text'] = df['text'].str.replace('¢', '')
df['text'] = df['text'].str.replace('£', '$')
df['text'] = df['text'].str.replace('¥', '$')
df['text'] = df['text'].str.replace('€', '$')
df['text'] = df['text'].str.replace('⁉', '?!')
df['text'] = df['text'].str.replace('‼', '!!')
df['text'] = df['text'].str.replace('…', '...')
df['text'] = df['text'].str.replace('½', '1/2')
df['text'] = df['text'].str.replace('¼', '1/4')
df['text'] = df['text'].str.replace('⅛', '1/8')
df['text'] = df['text'].str.replace('¾', '3/4')
df['text'] = df['text'].str.replace('⅔', '2/3')
df['text'] = df['text'].str.replace('²', '**2')
df['text'] = df['text'].str.replace('б', '6')
df['text'] = df['text'].str.replace('н', 'H')
df['text'] = df['text'].str.replace('ѕ', 's')
df['text'] = df['text'].str.replace('🇸', 's')
df['text'] = df['text'].str.replace('🇱', 'L')
df['text'] = df['text'].str.replace('🇺', 'U')
df['text'] = df['text'].str.replace('🇹', 'T')
df['text'] = df['text'].str.replace('🇷', 'R')
df['text'] = df['text'].str.replace('🇳', 'N')
df['text'] = df['text'].str.replace('🇲', 'M')
df['text'] = df['text'].str.replace('М', 'M')
df['text'] = df['text'].str.replace('Т', 'T')
df['text'] = df['text'].str.replace('🇽', 'X')
df['text'] = df['text'].str.replace('ñ', 'n')
df['text'] = df['text'].str.replace('ň', 'n')
df['text'] = df['text'].str.replace('ń', 'n')
df['text'] = df['text'].str.replace('Ñ', 'N')
df['text'] = df['text'].str.replace('Ν', 'N')
df['text'] = df['text'].str.replace('Ń', 'N')
df['text'] = df['text'].str.replace('ş', 's')
df['text'] = df['text'].str.replace('š', 's')
df['text'] = df['text'].str.replace('ś', 's')
df['text'] = df['text'].str.replace('ș', 's')
df['text'] = df['text'].str.replace('Ś', 'S')
df['text'] = df['text'].str.replace('Š', 'S')
df['text'] = df['text'].str.replace('Ş', 'S')
df['text'] = df['text'].str.replace('ğ', 'g')
df['text'] = df['text'].str.replace('é', 'e')
df['text'] = df['text'].str.replace('ú', 'u')
df['text'] = df['text'].str.replace('û', 'u')
df['text'] = df['text'].str.replace('ù', 'u')
df['text'] = df['text'].str.replace('ũ', 'u')
df['text'] = df['text'].str.replace('à', 'a')
df['text'] = df['text'].str.replace('á', 'a')
df['text'] = df['text'].str.replace('ā', 'a')
df['text'] = df['text'].str.replace('â', 'a')
df['text'] = df['text'].str.replace('ã', 'a')
df['text'] = df['text'].str.replace('å', 'a')
df['text'] = df['text'].str.replace('а', 'a')
df['text'] = df['text'].str.replace('ă', 'a')
df['text'] = df['text'].str.replace('Ā', 'A')
df['text'] = df['text'].str.replace('Å', 'A')
df['text'] = df['text'].str.replace('Á', 'A')
df['text'] = df['text'].str.replace('Ã', 'A')
df['text'] = df['text'].str.replace('Â', 'A')
df['text'] = df['text'].str.replace('À', 'A')
df['text'] = df['text'].str.replace('Ă', 'A')
df['text'] = df['text'].str.replace('Ă', 'A')
df['text'] = df['text'].str.replace('í', 'i')
df['text'] = df['text'].str.replace('ì', 'i')
df['text'] = df['text'].str.replace('ị', 'i')
df['text'] = df['text'].str.replace('ì', 'i')
df['text'] = df['text'].str.replace('î', 'i')
df['text'] = df['text'].str.replace('ï', 'i')
df['text'] = df['text'].str.replace('ī', 'i')
df['text'] = df['text'].str.replace('İ', 'I')
df['text'] = df['text'].str.replace('Í', 'I')
df['text'] = df['text'].str.replace('Î', 'I')
df['text'] = df['text'].str.replace('ê', 'e')
df['text'] = df['text'].str.replace('è', 'e')
df['text'] = df['text'].str.replace('ë', 'e')
df['text'] = df['text'].str.replace('ė', 'e')
df['text'] = df['text'].str.replace('е', 'e')
df['text'] = df['text'].str.replace('ё', 'e')
df['text'] = df['text'].str.replace('ě', 'e')
df['text'] = df['text'].str.replace('É', 'E')
df['text'] = df['text'].str.replace('È', 'E')
df['text'] = df['text'].str.replace('Ê', 'E')
df['text'] = df['text'].str.replace('ç', 'c')
df['text'] = df['text'].str.replace('ć', 'c')
df['text'] = df['text'].str.replace('č', 'c')
df['text'] = df['text'].str.replace('с', 'c')
df['text'] = df['text'].str.replace('¢', 'c')
df['text'] = df['text'].str.replace('Ç', 'C')
df['text'] = df['text'].str.replace('Č', 'C')
df['text'] = df['text'].str.replace('ó', 'o')
df['text'] = df['text'].str.replace('ō', 'o')
df['text'] = df['text'].str.replace('ô', 'o')
df['text'] = df['text'].str.replace('õ', 'o')
df['text'] = df['text'].str.replace('ő', 'o')
df['text'] = df['text'].str.replace('ò', 'o')
df['text'] = df['text'].str.replace('○', 'o')
df['text'] = df['text'].str.replace('Ó', 'O')
df['text'] = df['text'].str.replace('Ô', 'O')
df['text'] = df['text'].str.replace('đ', 'd')
df['text'] = df['text'].str.replace('ď', 'd')
df['text'] = df['text'].str.replace('ť', 't')
df['text'] = df['text'].str.replace('ț', 't')
df['text'] = df['text'].str.replace('Ť', 'T')
df['text'] = df['text'].str.replace('ř', 'r')
df['text'] = df['text'].str.replace('ŕ', 'r')
df['text'] = df['text'].str.replace('Ř', 'R')
df['text'] = df['text'].str.replace('ł', 'l')
df['text'] = df['text'].str.replace('ı', 'l')
df['text'] = df['text'].str.replace('Ł', 'L')
df['text'] = df['text'].str.replace('×', 'x')
df['text'] = df['text'].str.replace('у', 'y')
df['text'] = df['text'].str.replace('ž', 'z')
df['text'] = df['text'].str.replace('ż', 'z')
df['text'] = df['text'].str.replace('ẓ', 'z')
df['text'] = df['text'].str.replace('Ż', 'z')
df['text'] = df['text'].str.replace('Ź', 'z')
df['text'] = df['text'].str.replace('Ź', 'z')
df['text'] = df['text'].str.replace('Đ', 'D')
df['text'] = df['text'].str.replace('Ú', 'U')
df['text'] = df['text'].str.replace('ä', 'ae')
df['text'] = df['text'].str.replace('æ', 'ae')
df['text'] = df['text'].str.replace('Ä', 'Ae')
df['text'] = df['text'].str.replace('ö', 'oe')
df['text'] = df['text'].str.replace('œ', 'oe')
df['text'] = df['text'].str.replace('Ö', 'Oe')
df['text'] = df['text'].str.replace('ü', 'ue')
df['text'] = df['text'].str.replace('Ü', 'Ue')
df['text'] = df['text'].str.replace('ß', 'ss')
df['text'] = df['text'].str.replace('β', 'ss')
df['text'] = df['text'].str.replace('Ᏸ', 'ss')

# %%
# -*- coding: utf-8 -*-
def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# %%
english_text = []
english_label = []
not_english_text = []
not_english_label = []

print(len(df))
for i in range(len(df)):
  #print(i)
  if isEnglish(df['text'][i]) is True:
    #print('english')
    english_text.append(df['text'][i])
    english_label.append(df['label'][i])
  if isEnglish(df['text'][i]) is False:
    #print('not english')
    not_english_text.append(df['text'][i])
    not_english_label.append(df['label'][i])
  # else:
  #   print('Something unexpected happened')

df_english = pd.DataFrame(
{'text': english_text,
'label': english_label
})
df_not_english = pd.DataFrame(
{'text': not_english_text,
'label': not_english_label
})
# Out:
# 68604

# %%
df_not_english['text'][43]
# Out:
# 'أوروبا وخيار القوة في مواجهة اللاجئين تاريخ النشر: 26.10.2016 | 18:18 GMT | انسخ الرابط http://ar.rt.com/i5he قررت السلطاتُ الفرنسية اغلاقَ مخيماتِ اللجوء والهجرة في مدينة كاليه على الحدود الفرنسية البريطانية ومنعَ وصول اي لاجئين أو مهاجرين جدد اليها . جاء ذلك بناءً على قرار سياسي أعلنه الرئيسُ فرانسوا هولاند بتسوية هذا المسألة قبل حلول فصل الشتاء وبعدما تحول الملف الى ورقة بيد الأحزاب والتيارات السياسية اليمينية المتطرفة في فرنسا واوروبا بشكل عام. فرنسا حملت بريطانيا جزءا من المسؤولية ودعتها الى تحمل قسط من مسؤولياتها والتزاماتها الاخلاقية خاصة وان غالبية اللاجئين يرغبون في الوصول الى بريطانيا بأي شكل من الاشكال. ولعل اخطر مشكلة في هذا الملف هي قضية الاطفال السوريين الذين وصلوا الى كاليه من دون اي مرافق لهم واصبحوا عرضة لكل الاحتمالات حول مصيرهم المجهول وذلك بالرغم من إلحاح هيئات الاغاثة الانسانية والدعوة لإنقاذهم .'

# %%
def find_non_ascii_chars(text):
    return set([char for char in text if ord(char) > 127])

#print(find_non_ascii_chars('Müller'))
#print(find_non_ascii_chars(df_not_english['text'][1]))
for i in range(len(df_not_english)):
  print(i)
  print(find_non_ascii_chars(df_not_english['text'][i]))
# Out:
# 0
# {'¿'}
# 1
# {'¯', 'ツ'}
# 2
# {'π'}
# 3
# {'🇻', '۷', 'ᱚ', 'ɛ', 'ɱ', 'ɠ', 'λ', 'ղ', 'ɪ', 'я'}
# 4
# {'ن'}
# 5
# {'ח', 'ר', 'ן', 'א', 'ו', 'ז'}
# 6
# {'ﬁ'}
# 7
# {'め', '鯛', 'で'}
# 8
# {'¡'}
# 9
# {'أ', 'ى', 'غ', 'ف', 'ي', 'ض', 'و', 'ل', 'ة', 'ئ', 'د', 'ق', 'م', 'ث', 'ر', 'إ', 'ب', '،', 'ج', 'ع', 'ط', 'ن', 'س', 'ظ', 'ه', 'ا', 'ح', 'خ', 'ذ', '؟', 'ء', 'ك', 'ص', 'ت', 'ش'}
# 10
# {'і', 'Ӎ', 'Տ', 'Ԁ', 'Є', 'Ѧ', 'Ӊ'}
# 11
# {'в', 'д', 'щ', 'ш', 'ю', 'ч', 'х', 'п', 'э', 'л', 'ь', 'я', 'з', 'ы', 'р', 'о', 'к', 'т', 'С', 'ц', 'и', 'ж', 'й', 'В', 'П', 'г', 'м'}
# 12
# {'آ', 'ل', 'ا', 'خ', 'ف', 'ب', 'ة', 'ي', 'ك', 'ث'}
# 13
# {'ى', 'غ', 'ف', 'ص', 'ي', 'ز', 'و', 'ل', 'ة', 'ئ', 'د', 'م', 'ؤ', 'ث', 'ر', 'إ', 'ب', '،', 'ج', 'ع', 'ط', 'ن', 'س', 'ظ', 'ه', 'ذ', 'ا', 'ح', 'خ', 'ء', 'ك', 'ق', 'ت', 'ش'}
# 14
# {'点', '中', '本', '查', '版', '文', '看', '击'}
# 15
# {'ɴ', 'ᴇ', 'ʀ', 'ᴜ', 'ᴀ', 'ʏ', 'ᴅ', 'ᴛ'}
# 16
# {'в', 'ш', 'ч', 'х', 'п', 'л', 'Д', 'ь', 'р', 'о', 'Н', 'к', 'т', 'и', 'О', 'й', 'В', 'П', 'м'}
# ...

# %%
df_not_english
# Out:
#                                                   text label
# 0    U.S. President Barack Obama tried out his come...  true
# 1    Comedian Dave Chappelles highly anticipated   ...  true
# 2    BEIJING  -   A trip to Sun Xuns studio involve...  true
# 3    The hashtag #MyUnintendedJoy is trending on Tw...  true
# 4    Criminal   are generating around 35 billion US...  true
# ..                                                 ...   ...
# 322  Share on Facebook Edward Snowden demonstrated ...  fake
# 323  Videos Israel: Ancient Papyrus Proves Jerusale...  fake
# 324  Iraq bans alcohol Voltaire Network | 27 Octobe...  fake
# 325              Жидо6aHдeровцы - Jewish "banderites".  fake
# 326  Estonian tax-payers are covering medical costs...  fake
#
# [327 rows x 2 columns]

# %%
len(df)
# Out:
# 68604

# %%
len(df_english)
# Out:
# 68277

# %%
df_new = df_english

# %%
len(df_new)
# Out:
# 68277

# %%
# drop empty Strings
idx = np.where(df_new["text"] == '')
idx = idx[0][0]
print(idx)
print(df_new['text'][idx])

df_new = df_new.drop(index=idx)
df_new.reset_index(drop=True, inplace=True)
# Out:
# 58441

# %%
len(df_new)
# Out:
# 68276

# %%
train_df, test_df = train_test_split(df_new, test_size=0.2, random_state=42, shuffle=True)

# %%
#train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42, shuffle=False)

# %%
train_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)
#val_df.reset_index(drop=True, inplace=True)

# %%
train_df.label.value_counts()
# Out:
# true    27699
# fake    26921
# Name: label, dtype: int64

# %%
print(len(train_df))
train_df['label'].value_counts()
# Out:
# 54620
# true    27699
# fake    26921
# Name: label, dtype: int64

# %%
print(len(test_df))
test_df['label'].value_counts()
# Out:
# 13656
# fake    6861
# true    6795
# Name: label, dtype: int64

# %%
# print(len(val_df))
# val_df['label'].value_counts()

# %%
save_dir = root_dir + 'FIMI_Project_Datasets/'

# %%
train_df.to_csv(save_dir + "dataset_train.csv")
test_df.to_csv(save_dir + "dataset_test.csv")

# %%
test_train_df = pd.read_csv(save_dir + 'dataset_train.csv')
test_train_df = test_train_df.drop('Unnamed: 0', axis=1)

test_train_df
# Out:
#                                                     text label
# 0      We re going to have people who are bilingual t...  fake
# 1      And we wonder how we keep producing snowflakes...  fake
# 2      Russian firefighters on Sunday used specially ...  true
# 3      South Dakotas Republican Governor Dennis Dauga...  true
# 4      A hotel and nearby conference center on the so...  true
# ...                                                  ...   ...
# 54615  Whiny White House advisor Kellyanne Conway doe...  fake
# 54616  U.S. House Republicans on Friday won passage o...  true
# 54617  [White might burning courtesy Informed Content...  fake
# 54618  A New Jersey man who worked at the World Trade...  true
# 54619  U.S. President Donald Trump has developed a fr...  true
#
# [54620 rows x 2 columns]
